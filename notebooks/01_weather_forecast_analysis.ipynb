# %% [markdown]
# # 🌦️ Cambodia Weather Forecast Analysis
# ### Fundamentals of Data Science Project
# Cambodia Academy of Digital Technology (Group 4)

# %% [markdown]
# This notebook analyzes weather trends in Cambodia using government open data to explore climate patterns and forecasting insights.

# %%
# Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime

# %% [markdown]
# ## Fetch Weather Data
# Collect real-time weather data from Cambodia government API for analysis of temperature, humidity, and climate trends.

# %%
import requests

url = "https://data.mef.gov.kh/api/v1/realtime-api/weather"

# Disable SSL verification (not secure for production)
response = requests.get(url, verify=False)
data = response.json()

records = data.get("data", [])
df = pd.json_normalize(records)

print("Columns:", df.columns.tolist())
display(df.head())
# Out:
# c:\Python\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'data.mef.gov.kh'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Columns: ['wind_mph', 'precip_in', 'heatindex_f', 'id', 'last_updated_epoch', 'humidity', 'dewpoint_c', 'last_updated', 'wind_kph', 'cloud', 'dewpoint_f', 'name', 'temp_c', 'wind_degree', 'feelslike_c', 'vis_km', 'created_at', 'temp_f', 'wind_dir', 'feelslike_f', 'vis_miles', 'is_day', 'pressure_mb', 'windchill_c', 'uv', 'pressure_in', 'windchill_f', 'gust_mph', 'precip_mm', 'heatindex_c', 'gust_kph', 'condition.text', 'condition.icon', 'condition.code']
#    wind_mph  precip_in  heatindex_f      id  last_updated_epoch  humidity  \
# 0       6.7        0.0         85.2  747526          1773245700        40
# 1       8.9        0.0         86.2  747527          1773246600        51
# 2      12.3        0.0         86.5  747530          1773245700        69
# 3       2.2        0.0         77.5  747531          1773246600        87
# 4       2.2        0.0         85.5  747535          1773246600        47
#
#    dewpoint_c         last_updated  wind_kph  cloud  ...    uv pressure_in  \
# 0        14.5  2026-03-11T23:15:00      10.8     50  ...  None       29.85
# 1        17.8  2026-03-11T23:30:00      14.4     67  ...  None       29.85
# 2        21.5  2026-03-11T23:15:00      19.8     72  ...  None       29.86
# 3        20.8  2026-03-11T23:30:00       3.6     25  ...  None       29.89
# 4        16.5  2026-03-11T23:30:00       3.6     46  ...  None       29.85
#
#    windchill_f  gust_mph  precip_mm  heatindex_c gust_kph      condition.text  \
# 0         85.2      10.4       0.00         29.6     16.8       Partly Cloudy
# 1         84.2      13.9       0.07         30.1     22.4  Patchy rain nearby
# 2         81.9      17.9       0.03         30.3     28.7  Patchy rain nearby
# 3         73.7       3.3       0.00         25.3      5.4       Partly Cloudy
# 4         84.3       2.8       0.00         29.7      4.5       Partly Cloudy
#
#                                      condition.icon  condition.code
# 0  //cdn.weatherapi.com/weather/64x64/night/116.png            1003
# 1  //cdn.weatherapi.com/weather/64x64/night/176.png            1063
# 2  //cdn.weatherapi.com/weather/64x64/night/176.png            1063
# 3  //cdn.weatherapi.com/weather/64x64/night/116.png            1003
# 4  //cdn.weatherapi.com/weather/64x64/night/116.png            1003
#
# [5 rows x 34 columns]

# %%
# Check unique station names
if 'name' in df.columns:
    print("Available station names:")
    print(df['name'].unique())
else:
    print("No 'name' column found. Check API structure.")
# Out:
# Available station names:
# ['Kampong Cham' 'Phnom Penh' 'Takeo' 'Koh Kong' 'Banteay Meanchey'
#  'Prey Veng' 'Preah Vihear' 'Tboung Khmum' 'Sihanoukville' 'Siem Reap'
#  'Battambang' 'Kratie' 'Kampot' 'Kep' 'Kampong Thom' 'Svay Rieng'
#  'Mondulkiri' 'Kandal' 'Kampong Chhnang' 'Strung Treng' 'Pailin'
#  'Ratanakiri' 'Kampong Speu' 'Oddar Meanchey' 'Pursat']

# %% [markdown]
# ### Cleaning Data
# - 1
# - 2
# - 3

# %%
# Cleansing code

# %% [markdown]
# ## Exploratory Data Analysis
# - 1
# - 2
# - 3

# %%
# Exploratory Data Code

# # Daily average
# daily_avg = df.groupby(df["date.utc"].dt.date)["value"].mean()
# plt.figure(figsize=(12,5))
# daily_avg.plot()
# plt.title("Daily Average PM2.5 in Phnom Penh")
# plt.xlabel("Date")
# plt.ylabel("PM2.5 (µg/m³)")
# plt.show()

# # Monthly average
# monthly_avg = df.groupby("month")["value"].mean()
# plt.figure(figsize=(10,5))
# monthly_avg.plot(kind="bar", color="skyblue")
# plt.title("Monthly Average PM2.5")
# plt.xlabel("Month")
# plt.ylabel("PM2.5 (µg/m³)")
# plt.show()

# %%
# Code Here

# %% [markdown]
# # Conclusion
# - 1
# - 2
# - 3
